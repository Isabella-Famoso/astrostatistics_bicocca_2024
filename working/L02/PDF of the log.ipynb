# %% [markdown]
# ### Pdf of the log
# 1. Use `numpy` to draw $N$ (where $N$ is large...) random samples from a uniform distribution between $0.1$ and $10$, and store these samples as $x$.
# 2. Use matplotlib to make a histogram of these samples.
# 3. Compute the base-10 log of your array $x$, and store this as $y$.
# 4. Make another histogram for $y$. Using the equation to transform probability distributions, write what the theoretical pdf of $y$ is, and overplot it onto your histogram.
# 5. Compute the log of the mean of $x$ and the mean of $y$. Now compute the log of the median of $x$ and the median of $y$.
#
# You should note that the means are different, but the medians (as it is a cumulative statistic) are the same. The mean is affected by the scale of the sample values, but the median only depends on the ordering of the samples. Monotonic transformations (like taking the log) do not change the ordering of samples.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 1000
x = np.random.uniform(0.1, 10, N) #Creation of a uniform distribution

#Histogram of it
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca()
ax.hist(x, bins=50, density = True) 
#ax.legend()
ax.set_title('Uniform distribution histogram')

#log10(x)
y= np.log10(x)

#Histogram of log10(x)
fig1 = plt.figure(figsize=(8,6)) 
ax1 = fig1.gca()
ax1.hist(y, bins=50, density = True)
#ax.legend()
ax1.set_title('Log10 histogram')
# Out:
# Text(0.5, 1.0, 'Log10 histogram')

# %% [markdown]
# The pdf of x is:
# $p(x) = \frac{1}{10-0.1} = \frac{1}{0.9} $
#
# The pdf of y is:
# $p(y) = \left|dy/dx\right|^{-1}p(x) =\frac{ln(10)10^y}{0.9}$

# %%
#pdf of y
xgrid=np.linspace(-1, 1, 1000)
p_y= 10**xgrid * np.log(10)/(10-0.1)

#Plot of the pdf of y
fig1 = plt.figure(figsize=(8,6)) 
ax1 = fig1.gca()
ax1.hist(y, bins=50, density = True, label='Histogram')
ax1.plot(xgrid, p_y, label = 'Pdf of y')
ax1.legend()
ax1.set_title('Log10 histogram')
# Out:
# Text(0.5, 1.0, 'Log10 histogram')

# %%
mean_x = np.mean(x)
mean_y = np.mean(y)
print('The mean of y is:', mean_y)
print('The log of the mean of x is:', np.log10(mean_x))

median_x = np.median(x)
median_y = np.median(y)
print('The median of y is:', median_y)
print('The log of the median of x is:', np.log10(median_x))
# Out:
# The mean of y is: 0.5980484860100747
# The log of the mean of x is: 0.7047256391576898
# The median of y is: 0.7189724294320423
# The log of the median of x is: 0.7189742634154227
